# %%
from prometheus_pandas import query
import datetime as dt
from zoneinfo import ZoneInfo
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

local_address = "gros-82.nancy.grid5000.fr"
local_port = "30090"
p = query.Prometheus(f"http://admin:prom-operator@{local_address}:{local_port}")    

local_tz = ZoneInfo("Europe/Paris")

def execute_query_range(experiment, metric_query, step, output_filename, plot=False):
    tput_series = []

    print("\nBeginning request execution")
    for label, config in experiment.items():    
        df_metric = p.query_range(
            query=metric_query,
            start=config['start'].isoformat(),
            end=config['end'].isoformat(),
            step=step
        )

        tput_series.append(df_metric)

    if tput_series:
        combined_df = pd.concat(tput_series, axis=1)
        combined_df.to_csv(output_filename, index_label='Time')
        print(f"\nFile saved : '{output_filename}'")
        if plot:
            plt.figure(figsize=(12, 8))
            ax = combined_df.boxplot(grid=True, patch_artist=True)
            plt.title(metric_query)
            plt.show()
    else:
        print("\nRequest Error")

# %% [markdown]
# ### Experiment 1b

# %%
experiment_50k = {
    '1': {
        'start': dt.datetime(2025, 7, 17, 10, 41, 0, tzinfo=local_tz),
        'end': dt.datetime(2025, 7, 17, 10, 50, 0, tzinfo=local_tz)
    },
    '2': {
        'start': dt.datetime(2025, 7, 17, 11, 40, 0, tzinfo=local_tz),
        'end': dt.datetime(2025, 7, 17, 11, 50, 0, tzinfo=local_tz)
    },
    '3': {
        'start': dt.datetime(2025, 7, 17, 11, 11, 0, tzinfo=local_tz),
        'end': dt.datetime(2025, 7, 17, 11, 20, 0, tzinfo=local_tz)
    },
    '4': {
        'start': dt.datetime(2025, 7, 17, 11, 25, 0, tzinfo=local_tz),
        'end': dt.datetime(2025, 7, 17, 11, 35, 0, tzinfo=local_tz)
    }
}

experiment_10k = {
    '1': {
        'start': dt.datetime(2025, 7, 17, 14, 00, 0, tzinfo=local_tz),
        'end': dt.datetime(2025, 7, 17, 14, 10, 0, tzinfo=local_tz)
    },
    '2': {
        'start': dt.datetime(2025, 7, 17, 14, 15, 0, tzinfo=local_tz),
        'end': dt.datetime(2025, 7, 17, 14, 25, 0, tzinfo=local_tz)
    },
    '3': {
        'start': dt.datetime(2025, 7, 17, 14, 30, 0, tzinfo=local_tz),
        'end': dt.datetime(2025, 7, 17, 14, 40, 0, tzinfo=local_tz)
    },
    '4': {
        'start': dt.datetime(2025, 7, 17, 14, 45, 0, tzinfo=local_tz),
        'end': dt.datetime(2025, 7, 17, 14, 55, 0, tzinfo=local_tz)
    }
}

# %% [markdown]
# ### TPUT Measurement

# %%
metric_query = 'sum(flink_taskmanager_job_task_numRecordsOutPerSecond{component="taskmanager"})'
step = "5s"
output_filename = 'xp1bresults/50ktput/exp1b_50k_tput.csv'

execute_query_range(experiment_50k, metric_query, step, output_filename)
# Out:
# Beginning request execution
#
# File saved : 'xp1bresults/50ktput/exp1b_50k_tput.csv'

# %%
metric_query = 'sum(flink_taskmanager_job_task_numRecordsOutPerSecond{component="taskmanager"})'
step = "5s"
output_filename = 'xp1bresults/10ktput/exp1b_10k_tput.csv'

execute_query_range(experiment_10k, metric_query, step, output_filename)
# Out:
# Beginning request execution
#
# File saved : 'xp1bresults/10ktput/exp1b_10k_tput.csv'

# %% [markdown]
# ### CPU Load

# %%
metric_query = 'flink_taskmanager_Status_JVM_CPU_Load{component="taskmanager"}'
step = "5s"
output_filename = 'xp1bresults/50ktput/exp1b_50k_cpu_load.csv'

execute_query_range(experiment_50k, metric_query, step, output_filename)
# Out:
# Beginning request execution
#
# File saved : 'xp1bresults/50ktput/exp1b_50k_cpu_load.csv'

# %%
metric_query = 'flink_taskmanager_Status_JVM_CPU_Load{component="taskmanager"}'
step = "5s"
output_filename = 'xp1bresults/10ktput/exp1b_10k_cpu_load.csv'

execute_query_range(experiment_10k, metric_query, step, output_filename)
# Out:
# Beginning request execution
#
# File saved : 'xp1bresults/10ktput/exp1b_10k_cpu_load.csv'

# %% [markdown]
# ### Chepointing time

# %%
metric_query = 'flink_jobmanager_job_lastCheckpointDuration{component="jobmanager"}'
step = "30s"
output_filename = 'xp1bresults/50ktput/exp1b_50k_cp_time.csv'

execute_query_range(experiment_50k, metric_query, step, output_filename)
# Out:
# Beginning request execution
#
# File saved : 'xp1bresults/50ktput/exp1b_50k_cp_time.csv'

# %%
metric_query = 'flink_jobmanager_job_lastCheckpointDuration{component="jobmanager"}'
step = "30s"
output_filename = 'xp1bresults/10ktput/exp1b_10k_cp_time.csv'

execute_query_range(experiment_10k, metric_query, step, output_filename)
# Out:
# Beginning request execution
#
# File saved : 'xp1bresults/10ktput/exp1b_10k_cp_time.csv'

# %% [markdown]
# ### SST Files Size

# %%
metric_query = 'sum(flink_taskmanager_job_task_operator_column_family_rocksdb_total_sst_files_size{component="taskmanager"})'
step = "5s"
output_filename = 'xp1bresults/50ktput/exp1b_50k_sst_size.csv'

execute_query_range(experiment_50k, metric_query, step, output_filename)
# Out:
# Beginning request execution
#
# File saved : 'xp1bresults/50ktput/exp1b_50k_sst_size.csv'

# %%
metric_query = 'sum(flink_taskmanager_job_task_operator_column_family_rocksdb_total_sst_files_size{component="taskmanager"})'
step = "5s"
output_filename = 'xp1bresults/10ktput/exp1b_10k_sst_size.csv'

execute_query_range(experiment_10k, metric_query, step, output_filename)
# Out:
# Beginning request execution
#
# File saved : 'xp1bresults/10ktput/exp1b_10k_sst_size.csv'

# %% [markdown]
# ### Cache hit

# %%
metric_query = 'sum(rate(flink_taskmanager_job_task_operator_rocksdb_block_cache_hit{component="taskmanager"}[5m]))/(sum(rate(flink_taskmanager_job_task_operator_rocksdb_block_cache_miss{component="taskmanager"}[5m]))+sum(rate(flink_taskmanager_job_task_operator_rocksdb_block_cache_hit{component="taskmanager"}[5m])))'
step = "5s"
output_filename = 'xp1bresults/50ktput/exp1b_50k_hit_rate.csv'

execute_query_range(experiment_50k, metric_query, step, output_filename)
# Out:
# Beginning request execution
#
# File saved : 'xp1bresults/50ktput/exp1b_50k_hit_rate.csv'

# %%
metric_query = 'sum(rate(flink_taskmanager_job_task_operator_rocksdb_block_cache_hit{component="taskmanager"}[5m]))/(sum(rate(flink_taskmanager_job_task_operator_rocksdb_block_cache_miss{component="taskmanager"}[5m]))+sum(rate(flink_taskmanager_job_task_operator_rocksdb_block_cache_hit{component="taskmanager"}[5m])))'
step = "5s"
output_filename = 'xp1bresults/10ktput/exp1b_10k_hit_rate.csv'

execute_query_range(experiment_10k, metric_query, step, output_filename)
# Out:
# Beginning request execution
#
# File saved : 'xp1bresults/10ktput/exp1b_10k_hit_rate.csv'

# %% [markdown]
# ### Boxplot from file

# %%
file_path = 'xp1bresults/10ktput/exp1b_10k_sst_size.csv'

try:
    df = pd.read_csv(file_path, index_col=0)
    
    df.columns = ['634-22', '317-10', '50-100MB', 'no cache']
    
    plt.figure(figsize=(10, 7))
    df.boxplot(grid=True, patch_artist=True)
    
    plt.title('SST Files size per configuration with 10k e/s throughput')
    plt.ylabel('SST Files size (B)')
    plt.xlabel('Cache configuration (MB - GB)')
    #plt.yticks(np.arange(0, 1.2, 0.2))
    plt.savefig('xp1bresults/10ktput/exp1b_10k_sst_size.png')
    
    plt.show()
    
except FileNotFoundError:
    print(f"Le fichier '{file_path}' est introuvable.")
except Exception as e:
    print(f"Une erreur est survenue : {e}")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches


files_50k = {'xp1results/50ktput/exp1a_50k_cp_time.csv': '50k TPUT'}
files_10k = {'xp1results/10ktput/exp1a_10k_cp_time.csv': '10k TPUT'}
files_maxtput = {'xp1results/maxtput/exp1a_maxtput_cp_time.csv': 'Max TPUT'}

def load_and_prepare_data(file_dict):
    """Charge un fichier CSV et prépare les données pour le boxplot."""
    file_path = list(file_dict.keys())[0]
    try:
        df = pd.read_csv(file_path, index_col=0)
        df.columns = [col.split('{')[0].split('_')[-1] if '{' in col else col for col in df.columns]
        df.columns = ['rocks', 'forst', 'forst_no_cache']
        return df
    except FileNotFoundError:
        print(f"Erreur : Le fichier {file_path} est introuvable.")
        return None

df_50k = load_and_prepare_data(files_50k)
df_10k = load_and_prepare_data(files_10k)
df_maxtput = load_and_prepare_data(files_maxtput)

if df_50k is not None and df_10k is not None and df_maxtput is not None:
    labels = ['rocks', 'forst', 'forst_no_cache']
    data_50k = [df_50k[col].dropna() for col in labels]
    data_10k = [df_10k[col].dropna() for col in labels]
    data_maxtput = [df_maxtput[col].dropna() for col in labels]

    plt.figure(figsize=(16, 9))
    fig, ax = plt.subplots(figsize=(16, 9))

    x_positions = np.arange(len(labels))
    width = 0.25 

    bplot1 = ax.boxplot(data_maxtput, 
                        positions=x_positions - width, 
                        widths=width, 
                        patch_artist=True,
                        boxprops=dict(facecolor="cornflowerblue"))

    bplot2 = ax.boxplot(data_50k, 
                        positions=x_positions, 
                        widths=width, 
                        patch_artist=True,
                        boxprops=dict(facecolor="tomato"))

    bplot3 = ax.boxplot(data_10k, 
                        positions=x_positions + width, 
                        widths=width, 
                        patch_artist=True,
                        boxprops=dict(facecolor="lightgreen"))

    ax.set_ylabel('CP Time (ms)')
    ax.set_title('Comparison of Checkpointing time per configuration and throughput')
    
    ax.set_xticks(x_positions)
    ax.set_xticklabels(labels)
    ax.set_xlabel('Configuration')

    ax.yaxis.grid(True, linestyle='--')

    legend_50k = mpatches.Patch(color='cornflowerblue', label='Max TPUT')
    legend_10k = mpatches.Patch(color='tomato', label='50k TPUT')
    legend_maxtput = mpatches.Patch(color='lightgreen', label='10k TPUT')
    ax.legend(handles=[legend_50k, legend_10k, legend_maxtput])

    fig.tight_layout()
    plt.savefig('xp1results/boxplot_cp_time_comparison.png', dpi=300)
    plt.show()
# Out:
# Erreur : Le fichier xp1results/50ktput/exp1a_50k_cp_time.csv est introuvable.
# Erreur : Le fichier xp1results/10ktput/exp1a_10k_cp_time.csv est introuvable.
# Erreur : Le fichier xp1results/maxtput/exp1a_maxtput_cp_time.csv est introuvable.
